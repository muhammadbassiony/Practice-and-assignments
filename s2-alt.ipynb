# %%
import numpy as np    
import pandas as pd   
import seaborn as sns  
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv("E:\markov ml\creditcard.csv")

# %%
df.head(12)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
sns.countplot('Class' , data = df)

# %%
nrm_trx = df[df['Class'] == 0]
fraud_trx =  df[df['Class'] != 0 ]

# %%
#nrm_trx
fraud_trx
# Out:
#             Time        V1        V2         V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992  -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307   1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247  -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367  -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740  -4.304597  4.732795  3.624201 -1.357746
# 6331      7526.0  0.008430  4.137837  -6.240697  6.675732  0.768307 -3.353060
# 6334      7535.0  0.026779  4.132464  -6.560600  6.348557  1.329666 -2.513479
# 6336      7543.0  0.329594  3.712889  -5.775935  6.078266  1.667359 -2.420168
# 6338      7551.0  0.316459  3.809076  -5.615159  6.047445  1.554026 -2.651353
# 6427      7610.0  0.725646  2.300894  -5.329976  4.007683 -1.730411 -1.732193
# 6446      7672.0  0.702710  2.426433  -5.234513  4.416661 -2.170806 -2.667554
# ...

# %%
(fraud_trx/(fraud_trx+nrm_trx)) * 100
# Out:
#         Time  V1  V2  V3  V4  V5  V6  V7  V8  V9  ...    V21  V22  V23  V24  \
# 0        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 1        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 2        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 3        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 4        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 5        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 6        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 7        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 8        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 9        NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# 10       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...    NaN  NaN  NaN  NaN
# ...

# %%
plt.figure( figsize = (13,7) )
plt.subplot(121)
fraud_trx.Amount.plot.hist(title = "Fraudelent Transactions" , color = "red")
plt.subplot(122)
nrm_trx[nrm_trx['Amount']<= 2500].Amount.plot.hist(title = "Normal Transactions", color = "black")

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
df['nrm_Amount'] =StandardScaler().fit_transform( df['Amount'].values.reshape(-1,1) )

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9     ...           V23       V24       V25       V26  \
# ...

# %%
exg = pd.DataFrame(np.arange(12).reshape(3,4) , columns = ['A', 'B', 'C', 'D'])

# %%
exg
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
nrmdt = df.drop( ['Time','Amount','nrm_Amount'], axis = 1)
x = nrmdt.iloc[:, nrmdt.columns != 'Class']
y = nrmdt.iloc[:, nrmdt.columns == 'Class']

#z = nrmdt[nrmdt['Class'] == 1]

# %%
nrmdt.head(10)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10     ...            V21       V22       V23  \
# 0  0.098698  0.363787  0.090794     ...      -0.018307  0.277838 -0.110474
# ...

# %%
num_fraud = len(y[y['Class'] == 1])
num_nrm = len(y[y['Class'] == 0])

# %%
num_fraud
# Out:
# 492

# %%
num_nrm
# Out:
# 284315

# %%
fraud_indx = np.array(nrmdt[nrmdt.Class == 1].index)

# %%
fraud_indx
# Out:
# array([   541,    623,   4920,   6108,   6329,   6331,   6334,   6336,
#          6338,   6427,   6446,   6472,   6529,   6609,   6641,   6717,
#          6719,   6734,   6774,   6820,   6870,   6882,   6899,   6903,
#          6971,   8296,   8312,   8335,   8615,   8617,   8842,   8845,
#          8972,   9035,   9179,   9252,   9487,   9509,  10204,  10484,
#         10497,  10498,  10568,  10630,  10690,  10801,  10891,  10897,
#         11343,  11710,  11841,  11880,  12070,  12108,  12261,  12369,
#         14104,  14170,  14197,  14211,  14338,  15166,  15204,  15225,
#         15451,  15476,  15506,  15539,  15566,  15736,  15751,  15781,
#         15810,  16415,  16780,  16863,  17317,  17366,  17407,  17453,
#         17480,  18466,  18472,  18773,  18809,  20198,  23308,  23422,
#         26802,  27362,  27627,  27738,  27749,  29687,  30100,  30314,
#         30384,  30398,  30442,  30473,  30496,  31002,  33276,  39183,
# ...

# %%
nrm_indx = np.array(nrmdt[nrmdt.Class == 0].index)

# %%
nrm_indx
# Out:
# array([     0,      1,      2, ..., 284804, 284805, 284806], dtype=int64)

# %%
rand_nrm_indx = np.random.choice(nrm_indx, num_fraud)
len(rand_nrm_indx)
# Out:
# 492

# %%
balance_indx = np.concatenate([ rand_nrm_indx, fraud_indx])
len(balance_indx)
# Out:
# 984
